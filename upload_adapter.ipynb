# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# Set your adapter folder path and HuggingFace token
ADAPTER_PATH = '/content/drive/MyDrive/your_adapter_folder'
TOKEN = 'your_hf_write_token'
REPO_ID = 'tunedailabs/causal-reasoning-qwen-7b'

from huggingface_hub import HfApi, login, create_repo
login(token=TOKEN)
create_repo(repo_id=REPO_ID, repo_type='model', exist_ok=True, token=TOKEN)
api = HfApi()
api.upload_folder(folder_path=ADAPTER_PATH, repo_id=REPO_ID, repo_type='model', token=TOKEN)
print('Done!')
